# %%
# %matplotlib notebook

# %%
# Dependencies 
import csv 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# File to Load
df = pd.read_csv("Washington DC.csv")

#df_long = df.melt(id_vars = 'Household Income', var_name= 'Year', value_vars= 'Geography')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df
# Out:
#           Geography  Household Income  Year
# 0    Washington, DC              9161  2018
# 1    Washington, DC             52949  2018
# 2     United States           7598669  2018
# 3    Washington, DC             20875  2018
# 4     United States           5267344  2018
# ..              ...               ...   ...
# 187  Washington, DC             21222  2013
# 188   United States           5905618  2013
# 189  Washington, DC              8471  2013
# 190   United States           5484000  2013
# 191  Washington, DC             29650  2013
#
# [192 rows x 3 columns]

# %%
new_filtered = new_df[new_df['Year']>=2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered
# Out:
#           Geography  Household Income  Year
# 64   Washington, DC              9692  2016
# 65    United States          10312781  2016
# 66   Washington, DC             42579  2016
# 67    United States           6924913  2016
# 68    United States          14672995  2016
# ..              ...               ...   ...
# 187  Washington, DC             21222  2013
# 188   United States           5905618  2013
# 189  Washington, DC              8471  2013
# 190   United States           5484000  2013
# 191  Washington, DC             29650  2013
#
# [128 rows x 3 columns]

# %%
group_income = new_filtered.groupby(['Geography','Year'])['Household Income'].mean()
group_income = pd.DataFrame({'mean':group_income})

# %%
group_income
# Out:
#                              mean
# Geography      Year
# United States  2013  7.268190e+06
#                2014  7.328714e+06
#                2015  7.388016e+06
#                2016  7.428754e+06
# Washington, DC 2013  1.697819e+04
#                2014  1.733612e+04
#                2015  1.761169e+04
#                2016  1.757756e+04

# %%
# group_income = group_income.reset_index()
group_income.plot.bar(stacked = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# columns = new_filtered.columns.to_list()
# new_columns = []
# for i in columns:
#     new = i[len(i)-6:len(i)-4]
#     new_columns.append(new)
# new_columns[0] = 'City'
# new_columns[1] = 'State'
# new_filtered.columns = new_columns
# column_list = ['12', '13', '14', '15', '16']
# for i in column_list:
#     try:
#         new_filtered[str('20')+str(i)] =  new_filtered[i].mean(axis = 1).reset_index(drop = True)
#     except:
#         pass
# new_cities = new_filtered[['City', 'State', '2013', '2014', '2015', '2016']]
new_filtered.meanAdvance(row_list,column_list,axis=0)

# %%
df = pd.read_csv("New York.csv")

# %%
#df.columns

# %%
#df_long = df.melt(id_vars = 'Household Income', var_name= 'Year', value_name= 'Geography')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df

# %%
new_filtered = new_df[new_df['Year']>= 2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered

# %%
# File to Load
df = pd.read_csv("Nashville.csv")

# %%
#df_long = df.melt(id_vars = 'Household Income', var_name= 'year')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df

# %%
new_filtered = new_df[new_df['Year']>= 2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered

# %%
# File to Load
df = pd.read_csv("Atlanta.csv")

# %%
#df_long = df.melt(id_vars = 'Household Income', var_name= 'year')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df

# %%
new_filtered = new_df[new_df['Year']>= 2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered

# %%
# File to Load
df = pd.read_csv("Albuquerque.csv")

# %%
#df_long = df.melt(id_vars = 'Household Income', var_name= 'year')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df

# %%
new_filtered = new_df[new_df['Year']>= 2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered

# %%
# File to Load
df = pd.read_csv("San Diego .csv")

# %%
#df_long = df.melt(id_vars = 'Household Income', var_name= 'year')
new_df = df[['Geography','Household Income', 'Year']]

# %%
new_df

# %%
new_filtered = new_df[new_df['Year']>= 2013]
new_filtered = new_df[new_df['Year']<= 2016]
new_filtered
